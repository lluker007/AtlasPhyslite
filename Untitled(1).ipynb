# %%
#importing libraries
import os
import copy

import uproot
import awkward as ak
import vector
vector.register_awkward()
import matplotlib.pyplot as plt
import tqdm
import atlasopenmagic as atom
import requests

# %%
atom.get_current_release()
# Out:
# '2024r-pp'

# %%
atom.set_release('2025e-13tev-beta')
# Out:
# Active release set to: 2025e-13tev-beta. Metadata cache cleared.

# %%
url = atom.get_urls(410470, protocol = 'https')
file = url[0]
file
# Out:
# Fetching and caching all metadata for release: 2025e-13tev-beta...
# Successfully cached 374 datasets.
# 'https://opendata.cern.ch/eos/opendata/atlas/rucio/user/egramsta/mc_410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.noskim.root'

# %%
data_samples = atom.build_data_dataset('noskim', protocol = 'https')
# Out:
# DeprecationWarning: The build_data_dataset function is deprecated. Use build_dataset with the appropriate data definitions instead. (/srv/conda/envs/notebook/lib/python3.10/site-packages/atlasopenmagic/utils.py:161)

# %%
data_samples.keys()
# Out:
# dict_keys(['Data'])

# %%
value = data_samples['Data']['list'][0]
value
# Out:
# 'https://opendata.cern.ch/eos/opendata/atlas/rucio/user/egramsta/data15_periodD.noskim.root'

# %%
tree = uproot.open(value + ':analysis')

print(tree.num_entries)

print(tree.keys())
# Out:
# 45094640
# ['num_events', 'sum_of_weights', 'sum_of_weights_squared', 'category', 'TriggerMatch_DILEPTON', 'ScaleFactor_MLTRIGGER', 'ScaleFactor_PILEUP', 'ScaleFactor_FTAG', 'mcWeight', 'xsec', 'filteff', 'kfac', 'channelNumber', 'eventNumber', 'runNumber', 'trigML', 'trigP', 'trigDT', 'trigT', 'trigE', 'trigDM', 'trigDE', 'trigM', 'trigMET', 'ScaleFactor_BTAG', 'ScaleFactor_JVT', 'jet_n', 'jet_pt', 'jet_eta', 'jet_phi', 'jet_e', 'jet_btag_quantile', 'jet_jvt', 'largeRJet_n', 'largeRJet_pt', 'largeRJet_eta', 'largeRJet_phi', 'largeRJet_e', 'largeRJet_m', 'largeRJet_D2', 'jet_pt_jer1', 'jet_pt_jer2', 'ScaleFactor_ELE', 'ScaleFactor_MUON', 'ScaleFactor_LepTRIGGER', 'ScaleFactor_MuTRIGGER', 'ScaleFactor_ElTRIGGER', 'lep_n', 'lep_type', 'lep_pt', 'lep_eta', 'lep_phi', 'lep_e', 'lep_charge', 'lep_ptvarcone30', 'lep_topoetcone20', 'lep_z0', 'lep_d0', 'lep_d0sig', 'lep_isTightID', 'lep_isMediumID', 'lep_isLooseID', 'lep_isTightIso', 'lep_isLooseIso', 'lep_isTrigMatched', 'ScaleFactor_PHOTON', 'photon_n', 'photon_pt', 'photon_eta', 'photon_phi', 'photon_e', 'photon_ptcone20', 'photon_topoetcone40', 'photon_isLooseID', 'photon_isTightID', 'photon_isLooseIso', 'photon_isTightIso', 'ScaleFactor_TAU', 'ScaleFactor_TauTRIGGER', 'ScaleFactor_DiTauTRIGGER', 'tau_n', 'tau_pt', 'tau_eta', 'tau_phi', 'tau_e', 'tau_charge', 'tau_nTracks', 'tau_isTight', 'tau_RNNJetScore', 'tau_RNNEleScore', 'truth_jet_n', 'truth_jet_pt', 'truth_jet_eta', 'truth_jet_phi', 'truth_jet_m', 'truth_elec_n', 'truth_elec_pt', 'truth_elec_eta', 'truth_elec_phi', 'truth_muon_n', 'truth_muon_pt', 'truth_muon_eta', 'truth_muon_phi', 'truth_tau_n', 'truth_tau_pt', 'truth_tau_eta', 'truth_tau_phi', 'truth_photon_n', 'truth_photon_pt', 'truth_photon_eta', 'truth_photon_phi', 'truth_met', 'truth_met_phi', 'met', 'met_phi', 'met_mpx', 'met_mpy']

# %%
tree['lep_e'].arrays(library='ak')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 tree['lep_e'].arrays(library='ak')
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:825, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     823 if isinstance(self, TBranch) and expressions is None and len(keys) == 0:
#     824     filter_branch = uproot._util.regularize_filter(filter_branch)
# --> 825     return self.parent.arrays(
#     826         expressions=expressions,
#     827         cut=cut,
#     828         filter_name=filter_name,
#     829         filter_typename=filter_typename,
#     830         filter_branch=lambda branch: branch is self and filter_branch(branch),
#     831         aliases=aliases,
#     832         language=language,
#     833         entry_start=entry_start,
#     834         entry_stop=entry_stop,
#     835         decompression_executor=decompression_executor,
#     836         interpretation_executor=interpretation_executor,
#     837         array_cache=array_cache,
#     838         library=library,
#     839         how=how,
#     840     )
#     842 entry_start, entry_stop = _regularize_entries_start_stop(
#     843     self.tree.num_entries, entry_start, entry_stop
#     844 )
#     845 decompression_executor, interpretation_executor = _regularize_executors(
#     846     decompression_executor, interpretation_executor, self._file
#     847 )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:888, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     885                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     887 interp_options = {"ak_add_doc": ak_add_doc}
# --> 888 _ranges_or_baskets_to_arrays(
#     889     self,
#     890     ranges_or_baskets,
#     891     branchid_interpretation,
#     892     entry_start,
#     893     entry_stop,
#     894     decompression_executor,
#     895     interpretation_executor,
#     896     library,
#     897     arrays,
#     898     False,
#     899     interp_options,
#     900 )
#     902 # no longer needed; save memory
#     903 del ranges_or_baskets
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3198, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3195     pass
#    3197 elif isinstance(obj, tuple) and len(obj) == 3:
# -> 3198     uproot.source.futures.delayed_raise(*obj)
#    3200 else:
#    3201     raise AssertionError(obj)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/futures.py:38, in delayed_raise(exception_class, exception_value, traceback)
#      34 def delayed_raise(exception_class, exception_value, traceback):
#      35     """
#      36     Raise an exception from a background thread on the main thread.
#      37     """
# ---> 38     raise exception_value.with_traceback(traceback)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3106, in _ranges_or_baskets_to_arrays.<locals>.chunk_to_basket(chunk, branch, basket_num)
#    3104 try:
#    3105     cursor = uproot.source.cursor.Cursor(chunk.start)
# -> 3106     basket = uproot.models.TBasket.Model_TBasket.read(
#    3107         chunk,
#    3108         cursor,
#    3109         {"basket_num": basket_num},
#    3110         hasbranches._file,
#    3111         hasbranches._file,
#    3112         branch,
#    3113     )
#    3114     original_index = range_original_index[(chunk.start, chunk.stop)]
#    3115     if update_ranges_or_baskets:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/model.py:854, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     852     forth_obj.add_node(forth_stash)
#     853     forth_obj.push_active_node(forth_stash)
# --> 854 self.read_members(chunk, cursor, context, file)
#     855 if forth_obj is not None:
#     856     forth_obj.pop_active_node()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/models/TBasket.py:227, in Model_TBasket.read_members(self, chunk, cursor, context, file)
#     217 assert isinstance(self._parent, uproot.behaviors.TBranch.TBranch)
#     218 self._basket_num = context.get("basket_num")
#     220 (
#     221     self._members["fNbytes"],
#     222     self._key_version,
#     223     self._members["fObjlen"],
#     224     self._members["fDatime"],
#     225     self._members["fKeylen"],
#     226     self._members["fCycle"],
# --> 227 ) = cursor.fields(chunk, _tbasket_format1, context)
#     229 # skip the class name, name, and title
#     230 cursor.move_to(
#     231     self._cursor.index + self._members["fKeylen"] - _tbasket_format2.size - 1
#     232 )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/cursor.py:201, in Cursor.fields(self, chunk, format, context, move)
#     199 if move:
#     200     self._index = stop
# --> 201 return format.unpack(chunk.get(start, stop, self, context))
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/chunk.py:446, in Chunk.get(self, start, stop, cursor, context)
#     424 """
#     425 Args:
#     426     start (int): Seek position of the first byte to include.
#    (...)
#     443 already.
#     444 """
#     445 if (start, stop) in self:
# --> 446     self.wait(insist=stop)
#     447     local_start = start - self._start
#     448     local_stop = stop - self._start
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/chunk.py:388, in Chunk.wait(self, insist)
#     377 """
#     378 Args:
#     379     insist (bool or int): If True, raise an OSError if ``raw_data`` does
#    (...)
#     385 :ref:`uproot.source.chunk.Chunk.future` completes).
#     386 """
#     387 if self._raw_data is None:
# --> 388     self._raw_data = numpy.frombuffer(self._future.result(), dtype=self._dtype)
#     389     if insist is True:
#     390         requirement = len(self._raw_data) == self._stop - self._start
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/coalesce.py:39, in SliceFuture.result(self, timeout)
#      36 if uproot._util.wasm:
#      37     # Pyodide futures don't support timeout
#      38     return self._parent.result()[self._s]
# ---> 39 return self._parent.result(timeout=timeout)[self._s]
#
# TypeError: 'ClientResponseError' object is not subscriptable

# %%
print('TTree objects in file:')
for ii in uproot.open(file).keys():
    print(ii)

# %%
tree = uproot.open(file_path)['CollectionTree']
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tree = uproot.open(file_path)['CollectionTree']
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/reading.py:153, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     142 file = ReadOnlyFile(
#     143     file_path,
#     144     object_cache=object_cache,
#    (...)
#     149     **options,
#     150 )
#     152 if object_path is None:
# --> 153     return file.root_directory
#     154 else:
#     155     return file.root_directory[object_path]
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/reading.py:761, in ReadOnlyFile.root_directory(self)
#     755 @property
#     756 def root_directory(self):
#     757     """
#     758     The root ``TDirectory`` of the file
#     759     (:doc:`uproot.reading.ReadOnlyDirectory`).
#     760     """
# --> 761     return ReadOnlyDirectory(
#     762         (),
#     763         uproot.source.cursor.Cursor(self._fBEGIN + self._fNbytesName),
#     764         {},
#     765         self,
#     766         self,
#     767     )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/reading.py:1410, in ReadOnlyDirectory.__init__(self, path, cursor, context, file, parent)
#    1402 self.hook_before_header_key(
#    1403     chunk=chunk,
#    1404     cursor=cursor,
#    1405     keys_chunk=keys_chunk,
#    1406     keys_cursor=keys_cursor,
#    1407 )
#    1409 # header_key is never used, but we do need to seek past it
# -> 1410 ReadOnlyKey(keys_chunk, keys_cursor, {}, file, self, read_strings=True)
#    1412 num_keys = keys_cursor.field(
#    1413     keys_chunk, _directory_format_num_keys, context
#    1414 )
#    1416 self.hook_before_keys(
#    1417     chunk=chunk,
#    1418     cursor=cursor,
#    (...)
#    1421     num_keys=num_keys,
#    1422 )
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/reading.py:2274, in ReadOnlyKey.__init__(self, chunk, cursor, context, file, parent, read_strings)
#    2254 self._parent = parent
#    2256 self.hook_before_interpret(
#    2257     chunk=chunk,
#    2258     cursor=cursor,
#    (...)
#    2262     read_strings=read_strings,
#    2263 )
#    2265 (
#    2266     self._fNbytes,
#    2267     self._fVersion,
#    2268     self._fObjlen,
#    2269     self._fDatime,
#    2270     self._fKeylen,
#    2271     self._fCycle,
#    2272     self._fSeekKey,
#    2273     self._fSeekPdir,
# -> 2274 ) = cursor.fields(chunk, _key_format_small, context, move=False)
#    2276 if self.is_64bit:
#    2277     (
#    2278         self._fNbytes,
#    2279         self._fVersion,
#    (...)
#    2285         self._fSeekPdir,
#    2286     ) = cursor.fields(chunk, _key_format_big, context)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/cursor.py:201, in Cursor.fields(self, chunk, format, context, move)
#     199 if move:
#     200     self._index = stop
# --> 201 return format.unpack(chunk.get(start, stop, self, context))
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/chunk.py:446, in Chunk.get(self, start, stop, cursor, context)
#     424 """
#     425 Args:
#     426     start (int): Seek position of the first byte to include.
#    (...)
#     443 already.
#     444 """
#     445 if (start, stop) in self:
# --> 446     self.wait(insist=stop)
#     447     local_start = start - self._start
#     448     local_stop = stop - self._start
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/uproot/source/chunk.py:402, in Chunk.wait(self, insist)
#     396                 raise TypeError(
#     397                     f"""insist must be a bool or an int, not {insist!r}
#     398 for file path {self._source.file_path}"""
#     399                 )
#     401             if not requirement:
# --> 402                 raise OSError(
#     403                     f"""expected Chunk of length {self._stop - self._start},
#     404 received {len(self._raw_data)} bytes from {type(self._source).__name__}
#     405 for file path {self._source.file_path}"""
#     406                 )
#     407             self._future = None
#
# OSError: expected Chunk of length 934,
# received 0 bytes from FSSpecSource
# for file path /home/jovyan/DAOD_PHYSLITE.37620644._000012.pool.root.1
